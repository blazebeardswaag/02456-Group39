# %% [markdown]
# # Sampling from cifar
# Below are shown images sampled from our best performing cifar model.
#
# $$
# \begin{aligned}
# \text{Loss} = 0.048 \\
# \text{Epochs} = 352 \\
# \text{FID} = 49.175  \\
# \text{batch size} = 300
# \end{aligned}
# $$

# %%
from DiffusionModel import DenoisingDiffusion

diffusion = DenoisingDiffusion("cifar", "cpu")  # you can choose between [cifar, mnist], and [cpu, cuda]
diffusion.show_diffusion(num_images=9)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from DiffusionModel import DenoisingDiffusion
#       3 diffusion = DenoisingDiffusion("cifar", "cpu")  # you can choose between [cifar, mnist], and [cpu, cuda]
# ----> 4 diffusion.show_diffusion(num_images=9)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\DiffusionModel\denoising_diffusion.py:61, in DenoisingDiffusion.show_diffusion(self, num_images)
#      59 rgb = self.task == "cifar"
#      60 print(f"rgb is: {rgb}")
# ---> 61 show_diffusion_process(self.device, self.model, num_images, self.image_size, rgb=rgb)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\utils\helpers.py:323, in show_diffusion_process(device, model, num_images, image_size, rgb)
#     321 with torch.no_grad():
#     322     for t in range(1000, 0, -1):
# --> 323         x_t = process_timestep(x_t, t, model, sampler, image_gen, num_images, image_size, rgb)
#     325         if t in key_timesteps:
#     326             # Normalize and convert to numpy
#     327             imgs = x_t * std[:, None, None] + mean[:, None, None]
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\utils\helpers.py:244, in process_timestep(x_t, t, model, sampler, image_gen, num_images, image_size, rgb)
#     241 else:
#     242     model_input = x_t.view(x_t.size(0), -1)
# --> 244 eps_theta = model(model_input, t_tensor)
#     246 alpha_t = sampler.get_alpha(t_tensor).to(device)
#     247 alpha_bar_t = sampler.get_alpha_bar_t(t_tensor).to(device)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\models\unet_borrowed.py:350, in Unet.forward(self, x, t)
#     348 for idx, down in enumerate(self.downs):
#     349     down_outs.append(out)
# --> 350     out = down(out, t_emb)
#     351 # down_outs  [B x C1 x H x W, B x C2 x H/2 x W/2, B x C3 x H/4 x W/4]
#     352 # out B x C4 x H/4 x W/4
#     354 for mid in self.mids:
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\models\unet_borrowed.py:103, in DownBlock.forward(self, x, t_emb)
#     101 in_attn = self.attention_norms[i](in_attn)
#     102 in_attn = in_attn.transpose(1, 2)
# --> 103 out_attn, _ = self.attentions[i](in_attn, in_attn, in_attn)
#     104 out_attn = out_attn.transpose(1, 2).reshape(batch_size, channels, h, w)
#     105 out = out + out_attn
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\nn\modules\activation.py:1308, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1303         merged_mask, mask_type = self.merge_masks(
#    1304             attn_mask, key_padding_mask, query
#    1305         )
#    1307         if self.in_proj_bias is not None and self.in_proj_weight is not None:
# -> 1308             return torch._native_multi_head_attention(
#    1309                 query,
#    1310                 key,
#    1311                 value,
#    1312                 self.embed_dim,
#    1313                 self.num_heads,
#    1314                 self.in_proj_weight,
#    1315                 self.in_proj_bias,
#    1316                 self.out_proj.weight,
#    1317                 self.out_proj.bias,
#    1318                 merged_mask,
#    1319                 need_weights,
#    1320                 average_attn_weights,
#    1321                 mask_type,
#    1322             )
#    1324 any_nested = query.is_nested or key.is_nested or value.is_nested
#    1325 assert not any_nested, (
#    1326     "MultiheadAttention does not support NestedTensor outside of its fast path. "
#    1327     + f"The fast path was not hit because {why_not_fast_path}"
#    1328 )
#
# KeyboardInterrupt:

# %% [markdown]
# # Sampling from mnist
# Below are shown images sampled from our best performing mnist model.
#
# $$
# \begin{aligned}
# \text{Loss} = 0.023 \\
# \text{Epochs} = 158 \\
# \text{FID} = 19.8  \\
# \text{batch size} = 32 \\
# \end{aligned}
# $$

# %%
from DiffusionModel import DenoisingDiffusion

diffusion = DenoisingDiffusion("mnist", "cpu")  # you can choose between [cifar, mnist], and [cpu, cuda]
diffusion.show_diffusion(num_images=6)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from DiffusionModel import DenoisingDiffusion
#       3 diffusion = DenoisingDiffusion("mnist", "cpu")  # you can choose between [cifar, mnist], and [cpu, cuda]
# ----> 4 diffusion.show_diffusion(num_images=6)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\DiffusionModel\denoising_diffusion.py:61, in DenoisingDiffusion.show_diffusion(self, num_images)
#      59 rgb = self.task == "cifar"
#      60 print(f"rgb is: {rgb}")
# ---> 61 show_diffusion_process(self.device, self.model, num_images, self.image_size, rgb=rgb)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\utils\helpers.py:322, in show_diffusion_process(device, model, num_images, image_size, rgb)
#     320 with torch.no_grad():
#     321     for t in range(1000, 0, -1):
# --> 322         x_t = process_timestep(x_t, t, model, sampler, image_gen, num_images, image_size, rgb)
#     324         if t in key_timesteps:
#     325             # Normalize and convert to numpy
#     326             imgs = x_t * std[:, None, None] + mean[:, None, None]
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\utils\helpers.py:247, in process_timestep(x_t, t, model, sampler, image_gen, num_images, image_size, rgb)
#     244 eps_theta = model(model_input, t_tensor)
#     246 alpha_t = sampler.get_alpha(t_tensor).to(device)
# --> 247 alpha_bar_t = sampler.get_alpha_bar_t(t_tensor).to(device)
#     248 beta_t = sampler.linear_beta_scheduler(t).to(device)
#     249 z = torch.randn_like(x_t).to(device) if t > 1 else 0
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\sampler\sampler.py:16, in Sampler.get_alpha_bar_t(self, t_tensor)
#      13 def get_alpha_bar_t(self, t_tensor):
#      14     t = int(t_tensor[0].item())
# ---> 16     alphas = torch.tensor([self.get_alpha(t_i) for t_i in range(1, t + 1)], dtype=torch.float32)
#      17     alpha_bar_t = alphas.prod()
#      19     alpha_bar_results = torch.full((t_tensor.size(0),), alpha_bar_t, dtype=torch.float32)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\sampler\sampler.py:16, in <listcomp>(.0)
#      13 def get_alpha_bar_t(self, t_tensor):
#      14     t = int(t_tensor[0].item())
# ---> 16     alphas = torch.tensor([self.get_alpha(t_i) for t_i in range(1, t + 1)], dtype=torch.float32)
#      17     alpha_bar_t = alphas.prod()
#      19     alpha_bar_results = torch.full((t_tensor.size(0),), alpha_bar_t, dtype=torch.float32)
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\infra\sampler\sampler.py:25, in Sampler.get_alpha(self, t_tensor)
#      23 def get_alpha(self, t_tensor):
#      24     beta_t = self.linear_beta_scheduler(t_tensor)
# ---> 25     alpha_t = 1 - beta_t
#      26     return alpha_t
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\_tensor.py:39, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      37     if has_torch_function(args):
#      38         return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 39     return f(*args, **kwargs)
#      40 except TypeError:
#      41     return NotImplemented
#
# File c:\Users\ibrah\Documents\DTU\Deep learning\myenv\Lib\site-packages\torch\_tensor.py:1028, in Tensor.__rsub__(self, other)
#    1026 @_handle_torch_function_and_wrap_type_error_to_not_implemented
#    1027 def __rsub__(self, other):
# -> 1028     return _C._VariableFunctions.rsub(self, other)
#
# KeyboardInterrupt:
